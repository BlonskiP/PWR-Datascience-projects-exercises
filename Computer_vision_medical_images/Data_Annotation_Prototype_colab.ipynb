# %%
from PIL import Image
import numpy as np                         
from skimage import measure
from shapely.geometry import Polygon, MultiPolygon
import json
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Machine learning/data.zip"
# !unzip "/content/drive/MyDrive/Machine learning/data.zip"
# Out:
# Archive:  /content/drive/MyDrive/Machine learning/data.zip
#    creating: data/
#    creating: data/cortical_lesion/
#    creating: data/cortical_lesion/P001/
#   inflating: data/cortical_lesion/P001/P001.10006.bmp
#   inflating: data/cortical_lesion/P001/P001.10007.bmp
#   inflating: data/cortical_lesion/P001/P001.10008.bmp
#   inflating: data/cortical_lesion/P001/P001.10009.bmp
#   inflating: data/cortical_lesion/P001/P001.10010.bmp
#   inflating: data/cortical_lesion/P001/P001.10011.bmp
#   inflating: data/cortical_lesion/P001/P001.10012.bmp
#   inflating: data/cortical_lesion/P001/P001.10013.bmp
#   inflating: data/cortical_lesion/P001/P001.10014.bmp
#   inflating: data/cortical_lesion/P001/P001.10015.bmp
#   inflating: data/cortical_lesion/P001/P001.10016.bmp
#   inflating: data/cortical_lesion/P001/P001.10017.bmp
#   inflating: data/cortical_lesion/P001/P001.10018.bmp
#   inflating: data/cortical_lesion/P001/P001.10019.bmp
#   inflating: data/cortical_lesion/P001/P001.10020.bmp
#   inflating: data/cortical_lesion/P001/P001.10021.bmp
#    creating: data/cortical_lesion/P002/
#   inflating: data/cortical_lesion/P002/P002.10006.bmp
#   inflating: data/cortical_lesion/P002/P002.10007.bmp
#   inflating: data/cortical_lesion/P002/P002.10008.bmp
#   inflating: data/cortical_lesion/P002/P002.10009.bmp
#   inflating: data/cortical_lesion/P002/P002.10010.bmp
#   inflating: data/cortical_lesion/P002/P002.10011.bmp
#   inflating: data/cortical_lesion/P002/P002.10012.bmp
#   inflating: data/cortical_lesion/P002/P002.10013.bmp
#   inflating: data/cortical_lesion/P002/P002.10014.bmp
#   inflating: data/cortical_lesion/P002/P002.10015.bmp
#   inflating: data/cortical_lesion/P002/P002.10016.bmp
#   inflating: data/cortical_lesion/P002/P002.10017.bmp
#   inflating: data/cortical_lesion/P002/P002.10018.bmp
#   inflating: data/cortical_lesion/P002/P002.10019.bmp
#   inflating: data/cortical_lesion/P002/P002.10020.bmp
#   inflating: data/cortical_lesion/P002/P002.10021.bmp
#   inflating: data/cortical_lesion/P002/P002.10022.bmp
#    creating: data/cortical_lesion/P003/
#   inflating: data/cortical_lesion/P003/P003.10007.bmp
#   inflating: data/cortical_lesion/P003/P003.10008.bmp
#   inflating: data/cortical_lesion/P003/P003.10009.bmp
#   inflating: data/cortical_lesion/P003/P003.10010.bmp
#   inflating: data/cortical_lesion/P003/P003.10011.bmp
#   inflating: data/cortical_lesion/P003/P003.10012.bmp
#   inflating: data/cortical_lesion/P003/P003.10013.bmp
#   inflating: data/cortical_lesion/P003/P003.10014.bmp
#   inflating: data/cortical_lesion/P003/P003.10015.bmp
#   inflating: data/cortical_lesion/P003/P003.10016.bmp
#   inflating: data/cortical_lesion/P003/P003.10017.bmp
#   inflating: data/cortical_lesion/P003/P003.10018.bmp
#   inflating: data/cortical_lesion/P003/P003.10019.bmp
#   inflating: data/cortical_lesion/P003/P003.10020.bmp
#   inflating: data/cortical_lesion/P003/P003.10021.bmp
#    creating: data/cortical_lesion/P004/
#   inflating: data/cortical_lesion/P004/P004.10008.bmp
#   inflating: data/cortical_lesion/P004/P004.10009.bmp
#   inflating: data/cortical_lesion/P004/P004.10010.bmp
#   inflating: data/cortical_lesion/P004/P004.10011.bmp
#   inflating: data/cortical_lesion/P004/P004.10012.bmp
#   inflating: data/cortical_lesion/P004/P004.10013.bmp
#   inflating: data/cortical_lesion/P004/P004.10014.bmp
#   inflating: data/cortical_lesion/P004/P004.10015.bmp
#   inflating: data/cortical_lesion/P004/P004.10016.bmp
#   inflating: data/cortical_lesion/P004/P004.10017.bmp
#   inflating: data/cortical_lesion/P004/P004.10018.bmp
#   inflating: data/cortical_lesion/P004/P004.10019.bmp
#   inflating: data/cortical_lesion/P004/P004.10020.bmp
#   inflating: data/cortical_lesion/P004/P004.10021.bmp
#   inflating: data/cortical_lesion/P004/P004.10022.bmp
#   inflating: data/cortical_lesion/P004/P004.10023.bmp
#   inflating: data/cortical_lesion/P004/P004.10024.bmp
#    creating: data/cortical_lesion/P005/
#   inflating: data/cortical_lesion/P005/P005.10009.bmp
#   inflating: data/cortical_lesion/P005/P005.10010.bmp
#   inflating: data/cortical_lesion/P005/P005.10011.bmp
#   inflating: data/cortical_lesion/P005/P005.10012.bmp
#   inflating: data/cortical_lesion/P005/P005.10013.bmp
#   inflating: data/cortical_lesion/P005/P005.10014.bmp
#   inflating: data/cortical_lesion/P005/P005.10015.bmp
#   inflating: data/cortical_lesion/P005/P005.10016.bmp
#   inflating: data/cortical_lesion/P005/P005.10017.bmp
#   inflating: data/cortical_lesion/P005/P005.10018.bmp
#   inflating: data/cortical_lesion/P005/P005.10019.bmp
#   inflating: data/cortical_lesion/P005/P005.10020.bmp
#   inflating: data/cortical_lesion/P005/P005.10021.bmp
#   inflating: data/cortical_lesion/P005/P005.10022.bmp
#    creating: data/cortical_lesion/P006/
#   inflating: data/cortical_lesion/P006/P006.10006.bmp
#   inflating: data/cortical_lesion/P006/P006.10007.bmp
#   inflating: data/cortical_lesion/P006/P006.10008.bmp
#   inflating: data/cortical_lesion/P006/P006.10009.bmp
#   inflating: data/cortical_lesion/P006/P006.10010.bmp
#   inflating: data/cortical_lesion/P006/P006.10011.bmp
#   inflating: data/cortical_lesion/P006/P006.10012.bmp
#   inflating: data/cortical_lesion/P006/P006.10013.bmp
#   inflating: data/cortical_lesion/P006/P006.10014.bmp
#   inflating: data/cortical_lesion/P006/P006.10015.bmp
#   inflating: data/cortical_lesion/P006/P006.10016.bmp
#   inflating: data/cortical_lesion/P006/P006.10017.bmp
#   inflating: data/cortical_lesion/P006/P006.10018.bmp
#   inflating: data/cortical_lesion/P006/P006.10019.bmp
#   inflating: data/cortical_lesion/P006/P006.10020.bmp
esion/P053_Pytanie_Do_Radiologów/P053_Pytanie_Do_Radiologów.10018.bmp
#   inflating: data/cortical_lesion/P053_Pytanie_Do_Radiologów/P053_Pytanie_Do_Radiologów.10019.bmp
#    creating: data/cortical_lesion/P054/
#    creating: data/cortical_lesion/P055/
#   inflating: data/cortical_lesion/P055/P055.10007.bmp
#   inflating: data/cortical_lesion/P055/P055.10008.bmp
#   inflating: data/cortical_lesion/P055/P055.10009.bmp
#   inflating: data/cortical_lesion/P055/P055.10010.bmp
#   inflating: data/cortical_lesion/P055/P055.10011.bmp
#   inflating: data/cortical_lesion/P055/P055.10012.bmp
#   inflating: data/cortical_lesion/P055/P055.10013.bmp
#   inflating: data/cortical_lesion/P055/P055.10014.bmp
#   inflating: data/cortical_lesion/P055/P055.10015.bmp
#   inflating: data/cortical_lesion/P055/P055.10016.bmp
#   inflating: data/cortical_lesion/P055/P055.10017.bmp
#   inflating: data/cortical_lesion/P055/P055.10018.bmp
#    creating: data/cortical_lesion/P056/
#    creating: data/cortical_lesion/P058/
#   inflating: data/cortical_lesion/P058/P058.10005.bmp
#   inflating: data/cortical_lesion/P058/P058.10006.bmp
#   inflating: data/cortical_lesion/P058/P058.10007.bmp
#   inflating: data/cortical_lesion/P058/P058.10008.bmp
#   inflating: data/cortical_lesion/P058/P058.10009.bmp
#   inflating: data/cortical_lesion/P058/P058.10010.bmp
#   inflating: data/cortical_lesion/P058/P058.10011.bmp
#   inflating: data/cortical_lesion/P058/P058.10012.bmp
#   inflating: data/cortical_lesion/P058/P058.10013.bmp
#   inflating: data/cortical_lesion/P058/P058.10014.bmp
#   inflating: data/cortical_lesion/P058/P058.10015.bmp
#   inflating: data/cortical_lesion/P058/P058.10016.bmp
#   inflating: data/cortical_lesion/P058/P058.10017.bmp
#   inflating: data/cortical_lesion/P058/P058.10018.bmp
#    creating: data/cortical_lesion/P059/
#    creating: data/cortical_lesion/P060/
#    creating: data/cortical_lesion/P061/
#    creating: data/cortical_lesion/P062/
#    creating: data/cortical_lesion/P063/
#    creating: data/cortical_lesion/P064/
#   inflating: data/cortical_lesion/P064/P064.10006.bmp
#   inflating: data/cortical_lesion/P064/P064.10007.bmp
#   inflating: data/cortical_lesion/P064/P064.10008.bmp
#   inflating: data/cortical_lesion/P064/P064.10009.bmp
#   inflating: data/cortical_lesion/P064/P064.10010.bmp
#   inflating: data/cortical_lesion/P064/P064.10011.bmp
#   inflating: data/cortical_lesion/P064/P064.10012.bmp
#   inflating: data/cortical_lesion/P064/P064.10013.bmp
#   inflating: data/cortical_lesion/P064/P064.10014.bmp
#   inflating: data/cortical_lesion/P064/P064.10015.bmp
#   inflating: data/cortical_lesion/P064/P064.10016.bmp
#   inflating: data/cortical_lesion/P064/P064.10017.bmp
#    creating: data/cortical_lesion/P065/
#    creating: data/cortical_lesion/P066/
#    creating: data/cortical_lesion/P067/
#    creating: data/cortical_lesion/P068/
#    creating: data/subcortical_lesion/
#    creating: data/subcortical_lesion/P001/
#   inflating: data/subcortical_lesion/P001/P001.10006.bmp
#   inflating: data/subcortical_lesion/P001/P001.10007.bmp
#   inflating: data/subcortical_lesion/P001/P001.10008.bmp
#   inflating: data/subcortical_lesion/P001/P001.10009.bmp
#   inflating: data/subcortical_lesion/P001/P001.10010.bmp
#   inflating: data/subcortical_lesion/P001/P001.10011.bmp
#   inflating: data/subcortical_lesion/P001/P001.10012.bmp
#   inflating: data/subcortical_lesion/P001/P001.10013.bmp
#   inflating: data/subcortical_lesion/P001/P001.10014.bmp
#    creating: data/subcortical_lesion/P002/
#   inflating: data/subcortical_lesion/P002/P002.10006.bmp
#   inflating: data/subcortical_lesion/P002/P002.10008.bmp
#   inflating: data/subcortical_lesion/P002/P002.10009.bmp
#   inflating: data/subcortical_lesion/P002/P002.10010.bmp
#   inflating: data/subcortical_lesion/P002/P002.10011.bmp
#   inflating: data/subcortical_lesion/P002/P002.10012.bmp
#   inflating: data/subcortical_lesion/P002/P002.10013.bmp
#    creating: data/subcortical_lesion/P003/
#   inflating: data/subcortical_lesion/P003/P003.10006.bmp
#   inflating: data/subcortical_lesion/P003/P003.10007.bmp
#   inflating: data/subcortical_lesion/P003/P003.10008.bmp
#   inflating: data/subcortical_lesion/P003/P003.10009.bmp
#   inflating: data/subcortical_lesion/P003/P003.10010.bmp
#   inflating: data/subcortical_lesion/P003/P003.10011.bmp
#   inflating: data/subcortical_lesion/P003/P003.10012.bmp
#    creating: data/subcortical_lesion/P004/
#    creating: data/subcortical_lesion/P005/
#   inflating: data/subcortical_lesion/P005/P005.10006.bmp
#   inflating: data/subcortical_lesion/P005/P005.10007.bmp
#   inflating: data/subcortical_lesion/P005/P005.10008.bmp
#   inflating: data/subcortical_lesion/P005/P005.10009.bmp
#   inflating: data/subcortical_lesion/P005/P005.10010.bmp
#   inflating: data/subcortical_lesion/P005/P005.10011.bmp
#   inflating: data/subcortical_lesion/P005/P005.10012.bmp
#   inflating: data/subcortical_lesion/P005/P005.10013.bmp
#    creating: data/subcortical_lesion/P006/
#    creating: data/subcortical_lesion/P007/
#   inflating: data/subcortical_lesion/P007/P007.10005.bmp
#   inflating: data/subcortical_lesion/P007/P007.10006.bmp
#   inflating: data/subcortical_lesion/P007/P007.10007.bmp
#   inflating: data/subcortical_lesion/P007/P007.10008.bmp
#   inflating: data/subcortical_lesion/P007/P007.10009.bmp
#   inflating: data/subcortical_lesion/P007/P007.10010.bmp
#   inflating: data/subcortical_lesion/P007/P007.10011.bmp
#   inflating: data/subcortical_lesion/P007/P007.10012.bmp
#   inflating: data/subcortical_lesion/P007/P007.10013.bmp
#    creating: data/subcortical_lesion/P008/
#    creating: data/subcortical_lesion/P009/
#    creating: data/subcortical_lesion/P011/
#   inflating: data/subcortical_lesion/P011/P011.10006.bmp
#   inflating: data/subcortical_lesion/P011/P011.10007.bmp
#   inflating: data/subcortical_lesion/P011/P011.10008.bmp
#   inflating: data/subcortical_lesion/P011/P011.10009.bmp
#   inflating: data/subcortical_lesion/P011/P011.10010.bmp
#   inflating: data/subcortical_lesion/P011/P011.10011.bmp
#   inflating: data/subcortical_lesion/P011/P011.10012.bmp
#   inflating: data/subcortical_lesion/P011/P011.10013.bmp
#   inflating: data/subcortical_lesion/P011/P011.10014.bmp
#   inflating: data/subcortical_lesion/P011/P011.10015.bmp
#    creating: data/subcortical_lesion/P013/
#    creating: data/subcortical_lesion/P014/
#    creating: data/subcortical_lesion/P015/
#   inflating: data/subcortical_lesion/P015/P015.10009.bmp
#   inflating: data/subcortical_lesion/P015/P015.10010.bmp
#   inflating: data/subcortical_lesion/P015/P015.10011.bmp
#   inflating: data/subcortical_lesion/P015/P015.10012.bmp
#   inflating: data/subcortical_lesion/P015/P015.10013.bmp
#   inflating: data/subcortical_lesion/P015/P015.10014.bmp
#   inflating: data/subcortical_lesion/P015/P015.10015.bmp
#   inflating: data/subcortical_lesion/P015/P015.10016.bmp
#   inflating: data/subcortical_lesion/P015/P015.10017.bmp
#    creating: data/subcortical_lesion/P018/
#    creating: data/subcortical_lesion/P019/
#    creating: data/subcortical_lesion/P020/
#    creating: data/subcortical_lesion/P022/
#    creating: data/subcortical_lesion/P023/
#    creating: data/subcortical_lesion/P024/
#   inflating: data/subcortical_lesion/P024/P024.10006.bmp
#   inflating: data/subcortical_lesion/P024/P024.10007.bmp
#   inflating: data/subcortical_lesion/P024/P024.10008.bmp
#   inflating: data/subcortical_lesion/P024/P024.10009.bmp
#   inflating: data/subcortical_lesion/P024/P024.10010.bmp
#   inflating: data/subcortical_lesion/P024/P024.10011.bmp
#   inflating: data/subcortical_lesion/P024/P024.10012.bmp
#   inflating: data/subcortical_lesion/P024/P024.10013.bmp
#    creating: data/subcortical_lesion/P025/
#    creating: data/subcortical_lesion/P026/
#    creating: data/subcortical_lesion/P027/
#    creating: data/subcortical_lesion/P028/
#   inflating: data/subcortical_lesion/P028/P028.10007.bmp
#   inflating: data/subcortical_lesion/P028/P028.10008.bmp
#   inflating: data/subcortical_lesion/P028/P028.10009.bmp
#   inflating: data/subcortical_lesion/P028/P028.10010.bmp
#   inflating: data/subcortical_lesion/P028/P028.10011.bmp
#   inflating: data/subcortical_lesion/P028/P028.10012.bmp
#   inflating: data/subcortical_lesion/P028/P028.10013.bmp
#    creating: data/subcortical_lesion/P029/
#    creating: data/subcortical_lesion/P030/
#   inflating: data/subcortical_lesion/P030/P030.10006.bmp
#   inflating: data/subcortical_lesion/P030/P030.10007.bmp
#   inflating: data/subcortical_lesion/P030/P030.10008.bmp
#   inflating: data/subcortical_lesion/P030/P030.10009.bmp
#   inflating: data/subcortical_lesion/P030/P030.10010.bmp
#   inflating: data/subcortical_lesion/P030/P030.10011.bmp
#   inflating: data/subcortical_lesion/P030/P030.10012.bmp
#    creating: data/subcortical_lesion/P031/
#    creating: data/subcortical_lesion/P033/
#    creating: data/subcortical_lesion/P034/
#    creating: data/subcortical_lesion/P035/
#    creating: data/subcortical_lesion/P036/
#   inflating: data/subcortical_lesion/P036/P036.10007.bmp
#   inflating: data/subcortical_lesion/P036/P036.10008.bmp
#   inflating: data/subcortical_lesion/P036/P036.10009.bmp
#   inflating: data/subcortical_lesion/P036/P036.10010.bmp
#    creating: data/subcortical_lesion/P037/
#    creating: data/subcortical_lesion/P039/
#    creating: data/subcortical_lesion/P040/
#    creating: data/subcortical_lesion/P041/
#   inflating: data/subcortical_lesion/P041/P041.10005.bmp
#   inflating: data/subcortical_lesion/P041/P041.10006.bmp
#   inflating: data/subcortical_lesion/P041/P041.10007.bmp
#   inflating: data/subcortical_lesion/P041/P041.10008.bmp
#   inflating: data/subcortical_lesion/P041/P041.10009.bmp
#   inflating: data/subcortical_lesion/P041/P041.10010.bmp
#   inflating: data/subcortical_lesion/P041/P041.10011.bmp
#   inflating: data/subcortical_lesion/P041/P041.10012.bmp
#   inflating: data/subcortical_lesion/P041/P041.10013.bmp
#    creating: data/subcortical_lesion/P042/
#    creating: data/subcortical_lesion/P043/
#    creating: data/subcortical_lesion/P044/
#    creating: data/subcortical_lesion/P046/
#    creating: data/subcortical_lesion/P047/
#   inflating: data/subcortical_lesion/P047/P047.10007.bmp
#   inflating: data/subcortical_lesion/P047/P047.10008.bmp
#   inflating: data/subcortical_lesion/P047/P047.10009.bmp
#   inflating: data/subcortical_lesion/P047/P047.10010.bmp
#   inflating: data/subcortical_lesion/P047/P047.10011.bmp
#   inflating: data/subcortical_lesion/P047/P047.10012.bmp
#   inflating: data/subcortical_lesion/P047/P047.10013.bmp
#   inflating: data/subcortical_lesion/P047/P047.10014.bmp
#   inflating: data/subcortical_lesion/P047/P047.10015.bmp
#    creating: data/subcortical_lesion/P048/
#   inflating: data/subcortical_lesion/P048/P048.10005.bmp
#   inflating: data/subcortical_lesion/P048/P048.10006.bmp
#   inflating: data/subcortical_lesion/P048/P048.10007.bmp
#   inflating: data/subcortical_lesion/P048/P048.10008.bmp
#   inflating: data/subcortical_lesion/P048/P048.10009.bmp
#   inflating: data/subcortical_lesion/P048/P048.10010.bmp
#   inflating: data/subcortical_lesion/P048/P048.10011.bmp
#   inflating: data/subcortical_lesion/P048/P048.10012.bmp
#   inflating: data/subcortical_lesion/P048/P048.10013.bmp
#    creating: data/subcortical_lesion/P049/
#    creating: data/subcortical_lesion/P051/
#    creating: data/subcortical_lesion/P052/
#    creating: data/subcortical_lesion/P054/
#    creating: data/subcortical_lesion/P056/
#    creating: data/subcortical_lesion/P058/
#   inflating: data/subcortical_lesion/P058/P058.10005.bmp
#   inflating: data/subcortical_lesion/P058/P058.10006.bmp
#   inflating: data/subcortical_lesion/P058/P058.10007.bmp
#   inflating: data/subcortical_lesion/P058/P058.10008.bmp
#   inflating: data/subcortical_lesion/P058/P058.10009.bmp
#   inflating: data/subcortical_lesion/P058/P058.10010.bmp
#   inflating: data/subcortical_lesion/P058/P058.10011.bmp
#   inflating: data/subcortical_lesion/P058/P058.10012.bmp
#   inflating: data/subcortical_lesion/P058/P058.10013.bmp
#    creating: data/subcortical_lesion/P059/
#    creating: data/subcortical_lesion/P060/
#    creating: data/subcortical_lesion/P061/
#    creating: data/subcortical_lesion/P062/
#    creating: data/subcortical_lesion/P063/
#    creating: data/subcortical_lesion/P065/
#    creating: data/subcortical_lesion/P066/
#    creating: data/subcortical_lesion/P067/
#    creating: data/subcortical_lesion/P068/

# %%
colours = ( (255, 255, 255, "(255, 255, 255)"),
            (255, 0, 0, "(255, 0, 0)"),
            (0, 255, 0, "(0, 255, 0)"))

def nearest_colour( subjects, query ):
    return min( subjects, key = lambda subject: sum( (s - q) ** 2 for s, q in zip( subject, query ) ) )

def create_sub_masks(mask_image):
    width, height = mask_image.size

    # Initialize a dictionary of sub-masks indexed by RGB colors
    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            pixel = mask_image.getpixel((x,y))[:3]
            nearest_color = nearest_colour(colours,pixel)[3]
            # If the pixel is not white...(we have white background)
            if nearest_color != "(255, 255, 255)":
                # Check to see if we've created a sub-mask...
                
                pixel_str = nearest_color
                sub_mask = sub_masks.get(pixel_str)
                if sub_mask is None:
                   # Create a sub-mask (one bit per pixel) and add to the dictionary
                    # Note: we add 1 pixel of padding in each direction
                    # because the contours module doesn't handle cases
                    # where pixels bleed to the edge of the image
                    sub_masks[pixel_str] = Image.new('1', (width+2, height+2))

                # Set the pixel value to 1 (default is 0), accounting for padding
                sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks

# %%
def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
    #     measure.find_contours
    #Uses the “marching squares” method to compute a the iso-valued contours of 
    #the input 2D array for a particular level value. 
    contours = measure.find_contours(sub_mask, 0.5, positive_orientation='low')
    bboxes = []
    segmentations = []
    polygons = []
    areas = []
    annotations = []
    for contour in contours:
        # Flip from (row, col) representation to (x, y)
        # and subtract the padding pixel
        for i in range(len(contour)):
            row, col = contour[i]
            contour[i] = (col - 1, row - 1)

        # Make a polygon and simplify it
        #shapely.geometry Polygon
        
        poly = Polygon(contour)
        poly = poly.simplify(1.0, preserve_topology=False)
        segmentation = np.array(poly.exterior.coords).ravel().tolist()
        if len(segmentation)>1:
          segmentations.append([segmentation])
          polygons.append(poly)
    # Combine the polygons to calculate the bounding box and area
    offset = 0
    steps = 0
    for i , polygon in enumerate(polygons):
        bbox = []
        area = []
        if not polygon.is_empty:
            bbox = polygon.bounds
            area = polygon.area
        annotation = {
        'segmentation': segmentations[i],
        'iscrowd': 0,
        'image_id': image_id,
        'category_id': category_id,
        'id': annotation_id,
        'bbox': bbox,
        'area': area}
        annotations.append(annotation)
        steps +=1
        annotation_id += 1
    return annotations

# %%
errors=[
 ##To many colors masks...
 './data/cortical_lesion/P064/P064.10009.bmp', 
 './data/cortical_lesion/P018/P018.10016.bmp',
 #weird white mask
 './data/cortical_lesion/P003/P003.10011.bmp', #(255,250,250)
 #many weird masks
 './data/cortical_lesion/P003/P003.10013.bmp',
 #Multipolygo problem
 './data/cortical_lesion/P001/P001.10008.bmp',
 './data/cortical_lesion/P001/P001.10010.bmp',#(255, 97, 97)
 './data/cortical_lesion/P001/P001.10009.bmp'#(255, 164, 164)
 
 ]
errors=[]

# %%
coco_annotations={
    'info':{
        'description':'Dataset of brain lesions',
        'url':"",
        'year':2020,
        "contributor":"Dr. Martin Tabakow",
        "date_created": ""
    }, 
    'licenses':{
        'url':"",
        "id":0,
        'name':""
    },
    'images':[],
    'annotations':[],
    'categories':[]
}

# %%
coco_annotations['categories'].append({
    'supercategory':'brain damage',
    'id':1,
    'name':'cortical lesion'
})
coco_annotations['categories'].append({
    'supercategory':'brain damage',
    'id':2,
    'name':'subcortical lesion'
})

# %%
category_ids = {
        '(255, 0, 0)': 1,
        '(0, 255, 0)': 2
}

# %%
import os
from tqdm import tqdm
data_path = "./data/"
out_path = "/content/drive/MyDrive/Machine learning/brain_annotations.json"

with open(out_path,'w') as json_file:            
    json.dump(coco_annotations,json_file)

lesion_id = 1
is_crowd= 0
image_id = 1
annotation_id = 1
for (root,dirs,files) in tqdm(os.walk(data_path, topdown=True)):
    for filename in files:
        if filename.endswith('.bmp'):
          path = os.path.join(root, filename)
          if path not in errors:
            image={
            'license':0,
            'file_name':filename,
            'width':512,
            'height':512,
            'id':image_id
            }
            with Image.open(path) as mask_image:
              sub_masks = create_sub_masks(mask_image)
              for color, sub_mask in sub_masks.items():
               
                try:
                  category_id = category_ids[color]
                
                  annotations = create_sub_mask_annotation(sub_mask, image_id, category_id,annotation_id, is_crowd)
                except Exception as e:
                  print(e)
                  print(color,path)
                  continue
                annotation_id += len(annotations)
                for annotation in annotations:
                  with open(out_path,'r') as outfile:
                    data=json.load(outfile)
                    data['annotations'].append(annotation)
                  with open(out_path, "w") as outfile:
                    json.dump(data,outfile)
              with open(out_path,'r') as outfile:
                    data=json.load(outfile)
                    data['images'].append(image)
              with open(out_path, "w") as outfile:
                    json.dump(data,outfile)
              image_id+=1
# Out:
# 69it [21:29, 128.48s/it]
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P032/P032.10013.bmp
# 70it [25:22, 159.92s/it]
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P006/P006.10011.bmp
# 76it [47:30, 257.78s/it]
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P009/P009.10014.bmp
# 104it [2:56:35, 386.78s/it]
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P028/P028.10007.bmp
# 116it [3:32:44, 437.61s/it]
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P013/P013.10011.bmp
# 118it [4:12:46, 821.98s/it]
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P016/P016.10018.bmp
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P016/P016.10012.bmp
# 121it [4:25:31, 651.91s/it]
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P058/P058.10006.bmp
# 'MultiPolygon' object has no attribute 'exterior'
# (255, 0, 0) ./data/cortical_lesion/P058/P058.10016.bmp
# 125it [4:55:24, 141.79s/it]
