# %%
file = "covid19_2020_02_08.json.gz"

# %%
import pandas as pd
import gzip
import json

# %%
import json
import gzip
import pandas as pd

with gzip.GzipFile(file, 'r',) as fin:
    data_lan = []
    for line in fin:
        data_lan.append(json.loads(line.decode('utf-8')))

data = pd.DataFrame(data_lan)

# %%
data
# Out:
#                    tweet_id              user_id  \
# 0       1226007727287062528           1848266778
# 1       1226007727496888321           3252291385
# 2       1226007727580876800             70977553
# 3       1226007728000139265  1170179836251267072
# 4       1226007728444723203  1136943936256110592
# ...                     ...                  ...
# 759680  1226370112736808960   877001463586619392
# 759681  1226370111721889792             49695027
# 759682  1226370113235902464             25927619
# 759683  1226370114020265984            143718705
# 759684  1226370114246914048            277650091
#
#                                   date              keywords  \
# 0       Sat Feb 08 04:59:54 +0000 2020         [coronavirus]
# 1       Sat Feb 08 04:59:55 +0000 2020         [coronavirus]
# 2       Sat Feb 08 04:59:55 +0000 2020         [coronavirus]
# 3       Sat Feb 08 04:59:55 +0000 2020         [coronavirus]
# 4       Sat Feb 08 04:59:55 +0000 2020  [wuhan, coronavirus]
# ...                                ...                   ...
# 759680  Sun Feb 09 04:59:54 +0000 2020         [coronavirus]
# 759681  Sun Feb 09 04:59:54 +0000 2020                [sars]
# 759682  Sun Feb 09 04:59:54 +0000 2020         [coronavirus]
# 759683  Sun Feb 09 04:59:54 +0000 2020         [coronavirus]
# 759684  Sun Feb 09 04:59:54 +0000 2020  [coronavirus, wuhan]
#
#                                                  location
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 759680                                               None
# 759681                                               None
# 759682                                               None
# 759683                                               None
# 759684  {'country': 'Haiti', 'state': None, 'city': None}
#
# [759685 rows x 5 columns]
